# %%
import pandas as pd
import mathplotlib.pyplot as plt

# %%
df = pd.read_csv("Well_58-32_processed_pason_log.csv")

# %%
df.head()
# Out:
#    Depth(ft)  Depth(m)  ROP(1 ft)  ROP(1 m)  weight on bit (k-lbs)  \
# 0      85.18     25.96      56.80     17.31                    0.0
# 1      86.18     26.27      61.14     18.63                    0.0
# 2      87.23     26.59      18.58      5.66                    0.0
# 3      88.26     26.90      38.29     11.67                    0.0
# 4      89.36     27.24     394.38    120.20                    0.0
#
#    weight on bit (kg)  Temp Out( degF)  Temp Out( degC)  Temp In(degF)  \
# 0                 0.0            93.49            34.16          90.87
# 1                 0.0            93.52            34.18          90.83
# 2                 0.0            94.25            34.58          90.91
# 3                 0.0            94.44            34.69          91.14
# 4                 0.0            94.48            34.71          91.18
#
#    Temp In(degC)  ...  Surface Torque (KPa)  Rotary Speed (rpm)  \
# 0          32.71  ...                 61.57              151.09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7311 entries, 0 to 7310
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Depth(ft)              7311 non-null   float64
#  1   Depth(m)               7311 non-null   float64
#  2   ROP(1 ft)              7311 non-null   float64
#  3   ROP(1 m)               7311 non-null   float64
#  4   weight on bit (k-lbs)  7311 non-null   float64
#  5   weight on bit (kg)     7311 non-null   float64
#  6   Temp Out( degF)        7311 non-null   float64
#  7   Temp Out( degC)        7311 non-null   float64
#  8   Temp In(degF)          7311 non-null   float64
#  9   Temp In(degC)          7311 non-null   float64
#  10  Pit Total (bbls)       7311 non-null   float64
#  11  Pit Total (m3)         7311 non-null   float64
#  12  Pump Press (psi)       7311 non-null   float64
#  13  Pump Press (KPa)       7311 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Depth(ft)', 'Depth(m)', 'ROP(1 ft)', 'ROP(1 m)',
#        'weight on bit (k-lbs)', 'weight on bit (kg)', 'Temp Out( degF)',
#        'Temp Out( degC)', 'Temp In(degF)', 'Temp In(degC)', 'Pit Total (bbls)',
#        'Pit Total (m3)', 'Pump Press (psi)', 'Pump Press (KPa)',
#        'Hookload (k-lbs)', 'Hookload (kg)', 'Surface Torque (psi)',
#        'Surface Torque (KPa)', 'Rotary Speed (rpm)', 'Flow In (gal/min)',
#        'Flow In(liters/min)', 'Flow Out %', 'WH Pressure (psi)',
#        'WH Pressure (KPa)', 'H2S Floor', 'H2S Cellar', 'H2S Pits'],
#       dtype='object')

# %%
selected_cols =['Depth(m)', 'ROP(1 m)','weight on bit (kg)','Temp Out( degC)','Temp In(degC)', \
                'Pump Press (KPa)','Hookload (kg)','Surface Torque (KPa)', 'Rotary Speed (rpm)']
df = df[selected_cols]

# %%
df.head()
# Out:
#    Depth(m)  ROP(1 m)  weight on bit (kg)  Temp Out( degC)  Temp In(degC)  \
# 0     25.96     17.31                 0.0            34.16          32.71
# 1     26.27     18.63                 0.0            34.18          32.68
# 2     26.59      5.66                 0.0            34.58          32.73
# 3     26.90     11.67                 0.0            34.69          32.86
# 4     27.24    120.20                 0.0            34.71          32.88
#
#    Pump Press (KPa)  Hookload (kg)  Surface Torque (KPa)  Rotary Speed (rpm)
# 0           3197.35       14408.16                 61.57              151.09
# 1           3168.46       14063.49                 61.57              151.09
# 2           3134.26       14063.49                 62.12               61.54
# 3           3110.61       14131.52                 61.85               60.23
# 4           3144.74       14303.85                 61.85               61.75

# %%
df.tail()
# Out:
#       Depth(m)  ROP(1 m)  weight on bit (kg)  Temp Out( degC)  Temp In(degC)  \
# 7306   2295.71      3.29            13854.88            59.38          49.57
# 7307   2296.01      4.12            13709.75            59.38          49.52
# 7308   2296.32      3.85            13582.77            59.49          49.57
# 7309   2296.63      4.49            14086.17            59.62          49.63
# 7310   2296.94      3.95            13877.55            59.66          49.59
#
#       Pump Press (KPa)  Hookload (kg)  Surface Torque (KPa)  \
# 7306          10681.94       58335.60               1049.76
# 7307          10796.88       58480.73               1040.52
# 7308          10389.45       58607.71               1059.97
# 7309           9710.37       58104.31                999.78
# 7310           9626.73       58312.93               1025.01
#
#       Rotary Speed (rpm)
# 7306               34.91
# 7307               34.78
# 7308               34.72
# 7309               36.49
# ...

# %%
fig = fi
fig.plot(df["ROP(1 m)"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9565be1963c2> in <module>
# ----> 1 fig.plot(df["ROP(1 m)"])
#
# NameError: name 'fig' is not defined

# %%
df.corr()
# Out:
#                       Depth(m)  ROP(1 m)  weight on bit (kg)  Temp Out( degC)  \
# Depth(m)              1.000000 -0.508247            0.760430         0.371243
# ROP(1 m)             -0.508247  1.000000           -0.523441        -0.426404
# weight on bit (kg)    0.760430 -0.523441            1.000000         0.438218
# Temp Out( degC)       0.371243 -0.426404            0.438218         1.000000
# Temp In(degC)        -0.039279 -0.221713            0.148292         0.903097
# Pump Press (KPa)      0.705514 -0.493190            0.594060         0.580856
# Hookload (kg)         0.944648 -0.426580            0.593268         0.239998
# Surface Torque (KPa)  0.316396 -0.380201            0.321042         0.371688
# Rotary Speed (rpm)   -0.565349  0.289070           -0.459251        -0.184890
#
#                       Temp In(degC)  Pump Press (KPa)  Hookload (kg)  \
# Depth(m)                  -0.039279          0.705514       0.944648
# ...

# %%
time_df = pd.read_csv("Well_58-32_raw_pason_log.csv")
time_df.head()
# Out:
#       Date      Time  Depth (ft)  Depth (m)  Block Ht (ft)  Block Ht (m)  \
# 0  7/31/17  10:07:57        81.0      24.69        -9999.0      -2610.02
# 1  7/31/17  10:07:58        81.0      24.69        -9999.0      -2610.02
# 2  7/31/17  10:07:59        81.0      24.69        -9999.0      -2610.02
# 3  7/31/17  10:08:00        81.0      24.69        -9999.0      -2610.02
# 4  7/31/17  10:08:01        81.0      24.69        -9999.0      -2610.02
#
#    Bit Depth (ft)  Bit Depth (m)  ROP(1 ft)  ROP(1 m)  ...  Pit Total (bbls)  \
# 0             0.0            0.0        0.0       0.0  ...            187.92
# 1             0.0            0.0        0.0       0.0  ...            185.77
# 2             0.0            0.0        0.0       0.0  ...            184.84
# 3             0.0            0.0        0.0       0.0  ...            184.60
# 4             0.0            0.0        0.0       0.0  ...            184.24
#
#    Pit Total (m3)  Flow In (gal/min)  Flow In (liters/min)  \
# ...

# %%
time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397398 entries, 0 to 3397397
# Data columns (total 29 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Depth (ft)             float64
#  3   Depth (m)              float64
#  4   Block Ht (ft)          float64
#  5   Block Ht (m)           float64
#  6   Bit Depth (ft)         float64
#  7   Bit Depth (m)          float64
#  8   ROP(1 ft)              float64
#  9   ROP(1 m)               float64
#  10  Hookload (k lbs)       float64
#  11  Hookload (kg)          float64
#  12  Pump Pressure (psi)    float64
#  13  Pump Press (KPa)       float64
#  14  Surface Torque (psi)   float64
#  15  Surface Torque (KPa)   float64
#  16  Rotary Speed (rpm)     float64
#  17  Pump 1 (spm)           float64
#  18  Pump 2 (spm)           float64
#  19  Pit Total (bbls)       float64
#  20  Pit Total (m3)         float64
# ...

# %%
time_df[time_df["Depth (m)"]==25.96
# Out:
#           Date      Time  Depth (ft)  Depth (m)  Block Ht (ft)  Block Ht (m)  \
# 49072  7/31/17  23:50:13       85.18      25.96          57.25         14.94
#
#        Bit Depth (ft)  Bit Depth (m)  ROP(1 ft)  ROP(1 m)  ...  \
# 49072           85.18          25.96     1126.8    343.43  ...
#
#        Pit Total (bbls)  Pit Total (m3)  Flow In (gal/min)  \
# 49072            274.83           43.69            1109.58
#
#        Flow In (liters/min)  Flow Out (gal/min)  Flow Out (liters/min)  \
# 49072               4200.22              101.61                 384.64
#
#        Temp In (F)  Temp In (C)  Temp Out (F)  Temp Out (C)
# 49072        90.87        32.71         93.49         34.16
#
# [1 rows x 29 columns]

# %%
start = (time_df[time_df["Depth (m)"]==25.96].index)[0]
end = (time_df[time_df["Depth (m)"]==2296.94].index)[0]
new_time_df = time_df.iloc[start:end,:]

# %%
new_time_df[:20]
# Out:
#           Date      Time  Depth (ft)  Depth (m)  Block Ht (ft)  Block Ht (m)  \
# 49072  7/31/17  23:50:13       85.18      25.96          57.25         14.94
# 49073  7/31/17  23:50:14       85.40      26.03          57.03         14.89
# 49074  7/31/17  23:50:15       85.65      26.10          56.78         14.82
# 49075  7/31/17  23:50:16       85.78      26.14          56.65         14.79
# 49076  7/31/17  23:50:17       86.03      26.22          56.40         14.72
# 49077  7/31/17  23:50:18       86.18      26.27          56.25         14.68
# 49078  7/31/17  23:50:19       86.53      26.37          55.90         14.59
# 49079  7/31/17  23:50:20       86.53      26.37          55.71         14.54
# 49080  7/31/17  23:50:21       86.53      26.37          55.46         14.48
# 49081  7/31/17  23:50:22       86.53      26.37          55.34         14.45
# 49082  7/31/17  23:50:23       86.53      26.37          54.90         14.33
# ...

# %%
new_time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3331765 entries, 49072 to 3380836
# Data columns (total 29 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Depth (ft)             float64
#  3   Depth (m)              float64
#  4   Block Ht (ft)          float64
#  5   Block Ht (m)           float64
#  6   Bit Depth (ft)         float64
#  7   Bit Depth (m)          float64
#  8   ROP(1 ft)              float64
#  9   ROP(1 m)               float64
#  10  Hookload (k lbs)       float64
#  11  Hookload (kg)          float64
#  12  Pump Pressure (psi)    float64
#  13  Pump Press (KPa)       float64
#  14  Surface Torque (psi)   float64
#  15  Surface Torque (KPa)   float64
#  16  Rotary Speed (rpm)     float64
#  17  Pump 1 (spm)           float64
#  18  Pump 2 (spm)           float64
#  19  Pit Total (bbls)       float64
#  20  Pit Total (m3)         float64
# ...

# %%
time_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ecdc5d8e5a7> in <module>
# ----> 1 fd.describe()
#
# NameError: name 'fd' is not defined

# %%
time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397398 entries, 0 to 3397397
# Data columns (total 29 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Depth (ft)             float64
#  3   Depth (m)              float64
#  4   Block Ht (ft)          float64
#  5   Block Ht (m)           float64
#  6   Bit Depth (ft)         float64
#  7   Bit Depth (m)          float64
#  8   ROP(1 ft)              float64
#  9   ROP(1 m)               float64
#  10  Hookload (k lbs)       float64
#  11  Hookload (kg)          float64
#  12  Pump Pressure (psi)    float64
#  13  Pump Press (KPa)       float64
#  14  Surface Torque (psi)   float64
#  15  Surface Torque (KPa)   float64
#  16  Rotary Speed (rpm)     float64
#  17  Pump 1 (spm)           float64
#  18  Pump 2 (spm)           float64
#  19  Pit Total (bbls)       float64
#  20  Pit Total (m3)         float64
# ...
