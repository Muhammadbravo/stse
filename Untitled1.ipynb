# %%
import pandas as pd

# %%
df = pd.read_csv('production_data.txt', sep=',',
                 na_values = '?',)
df.head()
# Out:
#    Lease  Time (Days)  Choke Size  Gas Volume (MMscf)  Oil Volume (stb)  \
# 0  GOOSE          1.0         NaN               0.000                 0
# 1  GOOSE          2.0         NaN               6.988                 0
# 2  GOOSE          3.0         NaN               8.282                 0
# 3  GOOSE          4.0         NaN               8.298                 0
# 4  GOOSE          5.0         NaN               8.156                 0
#
#    Water Volume  (stb)  Gas Lift Inj Volume  (MMscf)  \
# 0                 85.0                           NaN
# 1                440.0                           NaN
# 2                296.0                           NaN
# 3                200.0                           NaN
# 4                125.0                           NaN
#
#    Casing Pressure  (psi(a))  Tubing Pressure  (psi(a))  \
# 0                        0.0                     2915.0
# 1                        0.0                     2933.0
# ...
